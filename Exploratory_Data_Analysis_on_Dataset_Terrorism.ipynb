# %% [markdown]
# # Data Science Intern at Let's Grow More LGMVIP Jul 23
# # Intermediate Level Task
# # Exploratory Data Analysis on Dataset - Terrorism
# # Sravani Pola

# %%
# Importing Libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Connecting Google Drive with Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importing Data Set from google drive
import os
os.chdir('/content/drive/My Drive')

# %%
# Reading Data set
data=pd.read_csv('/content/globalterrorismdb_0718dist.csv', encoding ='latin1')
data.head()
# Out:
# <ipython-input-7-baa99b42c699>:2: DtypeWarning: Columns (4,31,33,55,60,61,62,76,79,90,92,94,96,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('/content/globalterrorismdb_0718dist.csv', encoding ='latin1')
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0       0.0      0.0     0.0      NaN
# 1        0       1.0      1.0     1.0      NaN
# 2       -9      -9.0      1.0     1.0      NaN
# 3       -9      -9.0      1.0     1.0      NaN
# 4       -9      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
# Describing the data
data.describe()
# Out:
#             eventid         iyear        imonth          iday      extended  \
# count  5.541900e+04  55419.000000  55419.000000  55419.000000  55419.000000
# mean   1.985026e+11   1984.960429      6.418936     15.330139      0.016583
# std    5.558471e+08      5.558462      3.415463      8.825294      0.127703
# min    1.970000e+11   1970.000000      0.000000      0.000000      0.000000
# 25%    1.981071e+11   1981.000000      3.000000      8.000000      0.000000
# 50%    1.986033e+11   1986.000000      6.000000     15.000000      0.000000
# 75%    1.990023e+11   1990.000000      9.000000     23.000000      0.000000
# max    1.994031e+11   1994.000000     12.000000     31.000000      1.000000
#
#             country       region      latitude     longitude   specificity  \
# count  55419.000000  55419.00000  52445.000000  5.244400e+04  55419.000000
# mean     152.013245      5.47020     17.143388 -1.662983e+03      1.420451
# std      138.087424      3.20383     25.132533  3.763468e+05      1.100002
# min        4.000000      1.00000    -53.154613 -8.618590e+07      1.000000
# 25%       61.000000      3.00000      4.667128 -7.687283e+01      1.000000
# 50%      112.000000      5.00000     14.575278 -6.448779e+00      1.000000
# 75%      185.000000      8.00000     38.494167  3.011354e+01      1.000000
# max      605.000000     12.00000     64.837778  1.784419e+02      5.000000
#
#        ...     ransomamt  ransomamtus    ransompaid  ransompaidus  \
# count  ...  5.540000e+02          1.0  1.220000e+02           2.0
# mean   ...  3.308336e+06      20000.0  1.148937e+06           0.0
# std    ...  4.287434e+07          NaN  4.221767e+06           0.0
# min    ...  0.000000e+00      20000.0  0.000000e+00           0.0
# 25%    ...  0.000000e+00      20000.0  0.000000e+00           0.0
# 50%    ...  0.000000e+00      20000.0  3.585000e+04           0.0
# 75%    ...  5.000000e+05      20000.0  5.075000e+05           0.0
# max    ...  1.000000e+09      20000.0  4.100000e+07           0.0
#
#        hostkidoutcome    nreleased       INT_LOG      INT_IDEO      INT_MISC  \
# count     1309.000000  1001.000000  55419.000000  55418.000000  55418.000000
# mean         3.032850     8.557443     -3.264999     -3.223213      0.151359
# std          1.366816    32.850829      4.396730      4.446689      0.700439
# min          2.000000   -99.000000     -9.000000     -9.000000     -9.000000
# 25%          2.000000     1.000000     -9.000000     -9.000000      0.000000
# 50%          2.000000     1.000000      0.000000      0.000000      0.000000
# 75%          4.000000     2.000000      0.000000      0.000000      0.000000
# max          7.000000   390.000000      1.000000      1.000000      1.000000
#
#             INT_ANY
# count  55418.000000
# mean      -2.522700
# std        4.350286
# min       -9.000000
# 25%       -9.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 78 columns]

# %%
# Data Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55419 entries, 0 to 55418
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(23), object(57)
# memory usage: 57.1+ MB

# %%
# Data Types
data.dtypes
# Out:
# eventid         int64
# iyear           int64
# imonth          int64
# iday            int64
# approxdate     object
#                ...
# INT_LOG         int64
# INT_IDEO      float64
# INT_MISC      float64
# INT_ANY       float64
# related        object
# Length: 135, dtype: object

# %%
# Data Set Columns
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %%
# Taking out required Columns for Analysis
data=data[['eventid', 'iyear', 'imonth', 'country', 'region','provstate','city','crit1', 'crit2', 'crit3','success', 'suicide', 'attacktype1','targtype1','natlty1','gname','guncertain1','claimed','weaptype1','nkill','nwound']]
data.head()
# Out:
#         eventid  iyear  imonth  country  region provstate           city  \
# 0  197000000001   1970       7       58       2       NaN  Santo Domingo
# 1  197000000002   1970       0      130       1   Federal    Mexico city
# 2  197001000001   1970       1      160       5    Tarlac        Unknown
# 3  197001000002   1970       1       78       8    Attica         Athens
# 4  197001000003   1970       1      101       4   Fukouka        Fukouka
#
#    crit1  crit2  crit3  ...  suicide  attacktype1  targtype1  natlty1  \
# 0      1      1      1  ...        0            1         14     58.0
# 1      1      1      1  ...        0            6          7     21.0
# 2      1      1      1  ...        0            1         10    217.0
# 3      1      1      1  ...        0            3          7    217.0
# 4      1      1      1  ...        0            7          7    217.0
#
#                                 gname guncertain1  claimed  weaptype1  nkill  \
# 0                              MANO-D           0      NaN         13    1.0
# 1  23rd of September Communist League           0      NaN         13    0.0
# 2                             Unknown           0      NaN         13    1.0
# 3                             Unknown           0      NaN          6    NaN
# 4                             Unknown           0      NaN          8    NaN
#
#    nwound
# 0     0.0
# 1     0.0
# 2     0.0
# 3     NaN
# 4     NaN
#
# [5 rows x 21 columns]

# %%
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# country            0
# region             0
# provstate        270
# city               0
# crit1              0
# crit2              0
# crit3              0
# success            0
# suicide            0
# attacktype1        0
# targtype1          0
# natlty1          240
# gname              0
# guncertain1        0
# claimed        54138
# weaptype1          0
# nkill           5845
# nwound          7690
# dtype: int64

# %%
# Combining Two Columns i.e., 'nkill' and 'nwound' into a new column 'casualities'
data['nkill']=data['nkill'].fillna(0)
data['nwound']=data['nwound'].fillna(0)
data['casualities']=data['nkill']+data['nwound']
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# country            0
# region             0
# provstate        270
# city               0
# crit1              0
# crit2              0
# crit3              0
# success            0
# suicide            0
# attacktype1        0
# targtype1          0
# natlty1          240
# gname              0
# guncertain1        0
# claimed        54138
# weaptype1          0
# nkill              0
# nwound             0
# casualities        0
# dtype: int64

# %%
data.describe()
# Out:
#             eventid         iyear        imonth       country       region  \
# count  5.541900e+04  55419.000000  55419.000000  55419.000000  55419.00000
# mean   1.985026e+11   1984.960429      6.418936    152.013245      5.47020
# std    5.558471e+08      5.558462      3.415463    138.087424      3.20383
# min    1.970000e+11   1970.000000      0.000000      4.000000      1.00000
# 25%    1.981071e+11   1981.000000      3.000000     61.000000      3.00000
# 50%    1.986033e+11   1986.000000      6.000000    112.000000      5.00000
# 75%    1.990023e+11   1990.000000      9.000000    185.000000      8.00000
# max    1.994031e+11   1994.000000     12.000000    605.000000     12.00000
#
#               crit1         crit2         crit3       success       suicide  \
# count  55419.000000  55419.000000  55419.000000  55419.000000  55419.000000
# mean       0.990238      0.991230      0.857071      0.917898      0.000776
# std        0.098320      0.093235      0.350004      0.274522      0.027845
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      1.000000      1.000000      1.000000      0.000000
# 50%        1.000000      1.000000      1.000000      1.000000      0.000000
# 75%        1.000000      1.000000      1.000000      1.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#         attacktype1     targtype1       natlty1   guncertain1      claimed  \
# count  55419.000000  55419.000000  55179.000000  55419.000000  1281.000000
# mean       3.002634      7.682744    130.002882      0.045382    -0.020297
# std        1.874493      6.786203     74.499935      0.208141     1.649686
# min        1.000000      1.000000      4.000000      0.000000    -9.000000
# 25%        2.000000      2.000000     61.000000      0.000000     0.000000
# 50%        3.000000      4.000000    142.000000      0.000000     0.000000
# 75%        3.000000     14.000000    185.000000      0.000000     1.000000
# max        9.000000     22.000000    999.000000      1.000000     1.000000
#
#           weaptype1         nkill        nwound   casualities
# count  55419.000000  55419.000000  55419.000000  55419.000000
# mean       6.390895      1.835093      1.474891      3.309984
# std        2.177004      7.875346      9.724172     13.710286
# min        1.000000      0.000000      0.000000      0.000000
# 25%        5.000000      0.000000      0.000000      0.000000
# 50%        6.000000      0.000000      0.000000      0.000000
# 75%        6.000000      1.000000      0.000000      2.000000
# max       13.000000    422.000000    800.000000    800.000000

# %%
print(f"""
There are {data.country.nunique()} Countries from {data.region.nunique()} Regions covered in the dataset terrorist attack data in {data.claimed.nunique()} years from {data.iyear.min()} to {data.iyear.max()}. Overall {data.index.nunique()} terrorist attacks are recorded here which caused about {data.casualities.sum()} Casualities Consisted of {data.nkill.sum()} Kills and {data.nwound.sum()} Wounded.
""")
# Out:
# There are 178 Countries from 12 Regions covered in the dataset terrorist attack data in 3 years from 1970 to 1994. Overall 55419 terrorist attacks are recorded here which caused about 183436.0 Casualities Consisted of 101699.0 Kills and 81737.0 Wounded.

# %%
plt.subplots(figsize=(15, 6))
sns.countplot(x='iyear', data=data, palette='RdYlGn_r', edgecolor=sns.color_palette('dark', 10))
plt.xticks(rotation=90)
plt.title("Number of Terrorist Activities Each Year")
plt.show()

# %%
yearc=data[['iyear','casualities']].groupby('iyear').sum()
yearc.plot(kind='bar',color='red',figsize=(15,6))
plt.title("Casualities")
plt.xlabel('Years',fontsize=15)
plt.ylabel('No. of Casualities',fontsize=15)
plt.show()

# %%
data['attacktype1'].value_counts().plot(kind='bar',figsize=(20,10),color='blue')
plt.xticks(rotation=50)
plt.xlabel('Attack Type',fontsize=20)
plt.ylabel('Number of attacks')
plt.title('Number of attacks')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data' is your pandas DataFrame containing the 'targtype1' column

plt.subplots(figsize=(20, 10))
sns.countplot(data=data, x='targtype1', order=data['targtype1'].value_counts().index, palette='gist_heat', edgecolor=sns.color_palette("crest"))
plt.xticks(rotation=90)
plt.xlabel('Attack type', fontsize=20)
plt.ylabel('count')
plt.title('Type of attack')
plt.show()

# %%
plt.subplots(figsize=(15,6))
country_attacks = data.gname.value_counts()[:15].reset_index()
country_attacks.columns = ['gname', 'Total Attacks']
sns.barplot(x = country_attacks.gname, y = country_attacks['Total Attacks'], palette='OrRd_r', edgecolor=sns.color_palette('dark', 10))
plt.xticks(rotation = 90)
plt.title("Number of Total Attacks in Each Country")
plt.show()

# %%
sattk=data.success.value_counts()[:10]
sattk
# Out:
# 1    50869
# 0     4550
# Name: success, dtype: int64

# %%
data.gname.value_counts()[1:11]
# Out:
# Shining Path (SL)                                   4338
# Farabundo Marti National Liberation Front (FMLN)    3350
# Irish Republican Army (IRA)                         2524
# Basque Fatherland and Freedom (ETA)                 1627
# Palestinians                                        1022
# New People's Army (NPA)                              957
# Nicaraguan Democratic Force (FDN)                    895
# Revolutionary Armed Forces of Colombia (FARC)        854
# National Liberation Army of Colombia (ELN)           833
# Manuel Rodriguez Patriotic Front (FPMR)              815
# Name: gname, dtype: int64

# %% [markdown]
# # Conclusion
# # There are 178 Countries from 12 Regions covered in the dataset terrorist attack data in 3 years from 1970 to 1994. Overall 55419 terrorist attacks are recorded here which caused about 183436.0 Casualities Consisted of 101699.0 Kills and 81737.0 Wounded.
